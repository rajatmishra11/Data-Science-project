# %% [markdown]
# <a href="https://colab.research.google.com/github/rajatmishra11/Data-Science-project/blob/main/Formula_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np
import logging
logger= tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
celsius_q=np.array([-40, -10, 0 ,8,15,22,38], dtype=float)
far_a=np.array([-40,14,32,46,59,72,100], dtype=float)
for i,c in enumerate(celsius_q):
  print("{} degree Celsius ={} degrees Farhreneit". format(c,far_a[i]))
# Out:
# -40.0 degree Celsius =-40.0 degrees Farhreneit
# -10.0 degree Celsius =14.0 degrees Farhreneit
# 0.0 degree Celsius =32.0 degrees Farhreneit
# 8.0 degree Celsius =46.0 degrees Farhreneit
# 15.0 degree Celsius =59.0 degrees Farhreneit
# 22.0 degree Celsius =72.0 degrees Farhreneit
# 38.0 degree Celsius =100.0 degrees Farhreneit

# %%
l0=tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model=tf.keras.Sequential([l0])

# %%
model.compile(loss='mean_squared_error', optimizer = tf.keras.optimizers.Adam(0.1))

# %%
history= model.fit(celsius_q, far_a, epochs=10, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
import matplotlib.pyplot as plt
plt.xlabel('Epoch Number')
plt.ylabel('Loss Magnitude')
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 31ms/step
# [[211.78336]]

# %%
print("These are the layer variables:{}". format(l0.get_weights()))
# Out:
# These are the layer variables:[array([[1.7983047]], dtype=float32), array([31.952883], dtype=float32)]
