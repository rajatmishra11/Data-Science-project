# %%
#Machine Learning Algorithm on "HOUSING DATASET"
#Rajat Mishra ->2000320120133
#Vishesh Kumar ->2000320120193
#Utkarsh Sharma ->2000320120185

# %%
#importing  various libraries for Model
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting

# %%
#loading data set
df=pd.read_csv("HousingData.csv")

# %%
#showing first 5 rows of our dataset
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
#get info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
#checking how many NAN values are present in Respective Coloumn in dataset
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#dropping all NAN values 
df.dropna(inplace=True)

# %%
#checking how many NAN values are present in Respective Coloumn in dataset after dropping NAN values -> 0
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#seprate object for target feature
y=df["MEDV"]

#seprate object for input feature
x=df.drop("MEDV",axis=1)

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
x.head()    #indepent variable
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 5  394.12   5.21

# %%
y.head() #depedent variable
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 5    28.7
# Name: MEDV, dtype: float64

# %%
#importing 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=7)    #80% training

# %%
#imporing Linear Regression Model 

from sklearn.linear_model import LinearRegression

# %%
regression=LinearRegression()

# %%
y_train
# Out:
# 209    20.0
# 231    31.7
# 180    39.8
# 345    17.5
# 198    34.6
#        ...
# 270    21.1
# 80     28.0
# 29     21.0
# 252    29.6
# 222    27.5
# Name: MEDV, Length: 315, dtype: float64

# %%
#fitting variables into the model(Linear Regression)
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
#checking error 
from sklearn import metrics
print("Mean Absolute Error on Test Data of Linear Regression:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error on Test Data of Linear Regression:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error on Test Data of Linear Regression:",metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error on Test Data of Linear Regression: 3.1527638554435335
# Mean Squared Error on Test Data of Linear Regression: 15.79341946458286
# Root Mean Squared Error on Test Data of Linear Regression: 15.79341946458286

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred,'Variance':y_test-y_pred})
df1.head(10)
# Out:
#      Actual  Predicted  Variance
# 435    13.4  13.267506  0.132494
# 346    17.2  14.800035  2.399965
# 362    20.8  17.168301  3.631699
# 464    21.4  19.811536  1.588464
# 67     22.0  21.348961  0.651039
# 495    23.1  16.944862  6.155138
# 34     13.5  14.105464 -0.605464
# 70     24.2  25.685399 -1.485399
# 121    20.3  23.549935 -3.249935
# 182    37.9  33.475353  4.424647

# %%
fig,ax=plt.subplots(figsize=(20,10))
x_ax=range(len(x_test))
plt.scatter(x_ax,y_test,s=30,color="green",label="original")
plt.scatter(x_ax,y_pred,s=30,color="red",label="predicted")
plt.legend()
plt.grid()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,10))
x_ax=range(len(x_test))
plt.plot(x_ax,y_test,lw=1.2,color="green",label="original")
plt.plot(x_ax,y_pred,lw=1.2,color="red",label="predicted")
plt.legend()
plt.grid()
plt.show()

# %%
#train score of Regression Model
train_score=round(regression.score(x_train,y_train)*100,2)
print("Train score of LINEAR REGRESSION: ",train_score)
from sklearn.metrics import r2_score
score=round(r2_score(y_test,y_pred)*100,2)
print("r_2 score:",score)
print("Linear Regression Score:",regression.score(x_train,y_train))
# Out:
# Train score of LINEAR REGRESSION:  74.78
# r_2 score: 82.76
# Linear Regression Score: 0.7478223252552872

# %%
#2nd Algorithm -> Lasso
#importing 
from sklearn.linear_model import Lasso

# %%
Lasso=Lasso()

# %%
#fitting variables into the model(Linear Regression)
Lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
y_pred=Lasso.predict(x_test)

# %%
#checking error 
from sklearn import metrics
print("Mean Absolute Error on Test Data of Lasso Regression:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error on Test Data of Lasso Regression:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error on Test Data of Lasso Regression:",metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error on Test Data of Lasso Regression: 3.5235954151853064
# Mean Squared Error on Test Data of Lasso Regression: 23.768585952158627
# Root Mean Squared Error on Test Data of Lasso Regression: 23.768585952158627

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred,'Variance':y_test-y_pred})
df1.head(10)
# Out:
#      Actual  Predicted  Variance
# 435    13.4  11.826564  1.573436
# 346    17.2  17.655384 -0.455384
# 362    20.8  23.196839 -2.396839
# 464    21.4  20.280780  1.119220
# 67     22.0  22.762846 -0.762846
# 495    23.1  17.288449  5.811551
# 34     13.5  14.325188 -0.825188
# 70     24.2  24.289163 -0.089163
# 121    20.3  23.277881 -2.977881
# 182    37.9  31.889450  6.010550

# %%
fig,ax=plt.subplots(figsize=(20,10))
x_ax=range(len(x_test))
plt.plot(x_ax,y_test,lw=1.2,color="green",label="original")
plt.plot(x_ax,y_pred,lw=1.2,color="red",label="predicted")
plt.legend()
plt.grid()
plt.show()

# %%
#train score of Lasso Regression Model
train_score=round(Lasso.score(x_train,y_train)*100,2)
print("Train score of LASSO REGRESSION: ",train_score)
from sklearn.metrics import r2_score
score=round(r2_score(y_test,y_pred)*100,2)
print("r_2 score:",score)
print("Lasso Score:",round(Lasso.score(x_test,y_test)*100,2))
# Out:
# Train score of LASSO REGRESSION:  67.99
# r_2 score: 74.05
# Lasso Score: 74.05

# %%
#3rd Algorithm ->Ridge
#importing model
from sklearn.linear_model import Ridge

# %%
R=Ridge()
#fitting variables into the model(Linear Regression)
R.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred=R.predict(x_test)

# %%
#checking error 
from sklearn import metrics
print("Mean Absolute Error on Test Data of Ridge Regression:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error on Test Data of Ridge Regression:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error on Test Data of Ridge Regression:",metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error on Test Data of Ridge Regression: 3.045373721470829
# Mean Squared Error on Test Data of Ridge Regression: 15.135264048378003
# Root Mean Squared Error on Test Data of Ridge Regression: 15.135264048378003

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred,'Variance':y_test-y_pred})
df1.head()
# Out:
#      Actual  Predicted  Variance
# 435    13.4  13.909573 -0.509573
# 346    17.2  14.898824  2.301176
# 362    20.8  18.193679  2.606321
# 464    21.4  20.128515  1.271485
# 67     22.0  21.145468  0.854532

# %%
fig,ax=plt.subplots(figsize=(20,10))
x_ax=range(len(x_test))
plt.plot(x_ax,y_test,lw=1.2,color="green",label="original")
plt.plot(x_ax,y_pred,lw=1.2,color="red",label="predicted")
plt.legend()
plt.grid()
plt.show()

# %%
#train score of Ridge Regression Model
train_score=round(R.score(x_train,y_train)*100,2)
print("Train score of Ridge REGRESSION: ",train_score)
from sklearn.metrics import r2_score
score=round(r2_score(y_test,y_pred)*100,2)
print("r_2 score:",score)
print("Rigde Score:",round(R.score(x_test,y_test)*100,2))
# Out:
# Train score of Ridge REGRESSION:  74.35
# r_2 score: 83.48
# Rigde Score: 83.48

# %%
#4th Algorithm 
#importing 
from sklearn.linear_model import ElasticNet

# %%
E=ElasticNet()

# %%
#fitting variables into the model(Linear Regression)
E.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
y_pred=E.predict(x_test)

# %%
#checking error 
from sklearn import metrics
print("Mean Absolute Error on Test Data of ElasticNet Regression:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error on Test Data of ElasticNet Regression:",metrics.mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error on Test Data of ElasticNet Regression:",metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error on Test Data of ElasticNet Regression: 3.466236927047967
# Mean Squared Error on Test Data of ElasticNet Regression: 22.87969158249244
# Root Mean Squared Error on Test Data of ElasticNet Regression: 22.87969158249244

# %%
df1=pd.DataFrame({'Actual':y_test,'Predicted':y_pred,'Variance':y_test-y_pred})
df1.head()
# Out:
#      Actual  Predicted  Variance
# 435    13.4  12.035896  1.364104
# 346    17.2  17.182826  0.017174
# 362    20.8  23.180480 -2.380480
# 464    21.4  20.378336  1.021664
# 67     22.0  22.455210 -0.455210

# %%
fig,ax=plt.subplots(figsize=(20,10))
x_ax=range(len(x_test))
plt.plot(x_ax,y_test,lw=1.2,color="green",label="original")
plt.plot(x_ax,y_pred,lw=1.2,color="red",label="predicted")
plt.legend()
plt.grid()
plt.show()

# %%
#train score of Elastic Regression Model
train_score=round(E.score(x_train,y_train)*100,2)
print("Train score of Elastic REGRESSION: ",train_score)
from sklearn.metrics import r2_score
score=round(r2_score(y_test,y_pred)*100,2)
print("r_2 score:",score)
print("Elastic Score",round(E.score(x_test,y_test)*100,2))
# Out:
# Train score of Elastic REGRESSION:  68.68
# r_2 score: 75.02
# Elastic Score 75.02

# %%
#from above ML-Algorithms ,we conclude that RIGDE REGRESSION having best accuracy.
